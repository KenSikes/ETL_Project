# %%
import pandas as pd
pd.set_option('display.max_columns', None) #configures pandas to show all columns

# %%
kaggle_df = pd.read_csv(r'Resources/Kepler Exoplanets.csv')
data_world_df = pd.read_csv(r'Resources/cumulative.csv')

# %%
kaggle_df.head()
# Out:
#   pl_hostname pl_letter       pl_name pl_discmethod  pl_controvflag  pl_pnum  \
# 0  Kepler-128         b  Kepler-128 b       Transit               0        2
# 1  Kepler-128         c  Kepler-128 c       Transit               0        2
# 2  Kepler-129         b  Kepler-129 b       Transit               0        2
# 3  Kepler-129         c  Kepler-129 c       Transit               0        2
# 4  Kepler-130         b  Kepler-130 b       Transit               0        3
#
#    pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbpern  \
# 0  15.090000            NaN            NaN           0.0           6
# 1  22.804000            NaN            NaN           0.0           6
# 2  15.791860       0.000068      -0.000068           0.0           5
# 3  82.200170       0.000680      -0.000680           0.0           5
# 4   8.457458       0.000039      -0.000039           0.0           5
#
#    pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  pl_orbsmaxlim  pl_orbsmaxn  \
# ...

# %%
data_world_df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              1              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...

# %%
###--- *Keplar_name* in #kaggle_df# is the same as *pl_name* in #data_world_df# ---###
